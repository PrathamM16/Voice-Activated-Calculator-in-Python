# %%
pip install sympy
# Out:
# ...
#
# ...

# %%
pip install SpeechRecognition pyttsx3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import pyttsx3
import sympy as sp

def listen_command():
    recognizer = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        recognizer.adjust_for_ambient_noise(source)
        audio = recognizer.listen(source)
        try:
            command = recognizer.recognize_google(audio).lower()
            print(f"You said: {command}")
        except sr.UnknownValueError:
            print("Sorry, I didn't catch that. Please repeat.")
            return listen_command()
        except sr.RequestError:
            print("Sorry, there seems to be an issue with the speech recognition service.")
            return ""
        return command

def calculate(expression):
    try:
        # Replace words with arithmetic operators and sympy functions
        expression = expression.replace('plus', '+').replace('minus', '-')
        expression = expression.replace('times', '*').replace('divided by', '/')
        expression = expression.replace('x', '*').replace('over', '/')
        expression = expression.replace('root', 'sqrt').replace('square', '**2')
        
        # Convert the string expression to a sympy expression
        expr = sp.sympify(expression)
        result = expr.evalf()
        return result
    except Exception as e:
        print(f"Error: {e}")
        return "Error in calculation"

def speak_result(result):
    engine = pyttsx3.init()
    engine.say(f"The result is {result}")
    engine.runAndWait()

if __name__ == "__main__":
    while True:
        print("Please say a mathematical expression to calculate (or say 'exit' to quit):")
        command = listen_command()
        if 'exit' in command:
            print("Goodbye!")
            break
        elif command:
            result = calculate(command)
            print(f"Result: {result}")
            speak_result(result)
# Out:
# Please say a mathematical expression to calculate (or say 'exit' to quit):
# Listening...
# You said: 5 + 5 + 2 + 2 + 3 + 3 + 3
# Result: 23.0000000000000
# Please say a mathematical expression to calculate (or say 'exit' to quit):
# Listening...
# Sorry, I didn't catch that. Please repeat.
# Listening...
# You said: lenovo wi-fi
# Error: Sympify of expression 'could not parse 'lenovo wi-fi'' failed, because of exception being raised:
# SyntaxError: invalid syntax (<string>, line 1)
# Result: Error in calculation
# Please say a mathematical expression to calculate (or say 'exit' to quit):
# Listening...
# Sorry, I didn't catch that. Please repeat.
# Listening...
# Sorry, I didn't catch that. Please repeat.
# Listening...
# Sorry, I didn't catch that. Please repeat.
# Listening...
# Sorry, I didn't catch that. Please repeat.
# Listening...
# Sorry, I didn't catch that. Please repeat.
# Listening...
# Sorry, I didn't catch that. Please repeat.
# Listening...
# ...
